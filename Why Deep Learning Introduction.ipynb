# %%
# Deep Learning is a sub-field of AI and ML that is inspired by the structure of human brain.Deep learning algorithms attempts
# to draw similar conclusions as humans by continuiously analysing the data with a given logical structure called neural network.

# %%
# Deep learning algorithm automatically extracts features from given data unlike ML algorithm.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Existing Transfer Learning Architectures**
# ![image.png](attachment:image.png)

# %% [markdown]
# **DL Libraries/Frameworks**
# * Tenserflow(Developed by Google in 2015)
#     * Keras-developed by Google as a wrapper over tenserflow
#     * Google combined Tenserflow+Keras in 2019
#     * TF+Keras architecture is more used in industry
# * Pytorch by facebook in 2016
#     * pytorch lib is more used by researchers

# %% [markdown]
# **Types of DL Architectures**
# * 1. ANN/MLP(multi layer perceptron)
# * 2. CNN
# * 3. RNN...LSTM is a small variation of RNN
# * 4. Auto Encoders
# * 5. GAN(Generative Adversial Network)
